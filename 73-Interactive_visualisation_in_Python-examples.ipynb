# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>
#
# # Examples: Interactive visualisation in Python
#
# © ExploreAI Academy
#
# In this train, we will focus on creating unique and interactive visualisations. We will learn how to make our code block outputs interactive for the end user.
#
# > ⚠️ **Note:** An active internet connection is needed to complete the exercises within this notebook.
#
# > ⚠️ **Note:** This exercise works best when executed in a Jupyter notebook.

# %% [markdown]
# ## Learning objectives
# By the end of this train, you should be able to:
# * Create advanced custom visualisations in Python.
# * Create interactive visualisations in a Jupyter notebook.

# %% [markdown]
# ## Introduction
#
# Sometimes we require interaction in our Jupyter notebooks rather than a PowerBI dashboard. A potential reason would be to employ more sophisticated technology to meet typical business intelligence use cases. Traditional BI tools are ideal for creating dashboards created from SQL or CSV data. However, when we try to display information created by more sophisticated logic, we often fall short.
#
# With interactive widgets in a notebook, we can leverage the full power of Python to express calculations and build visualisations while exposing "our logic" to the end user, allowing them to modify aspects of the visualisation. We may either add a few interactive controls and plots to notebooks or build completely functional applications and interactive dashboards. Both can be created with components from the built-in core widgets, such as `buttons`, `sliders`, and `dropdowns`, or with the rich ecosystem of custom widget libraries based on the Jupyter widgets framework, such as interactive maps with `ipyleaflet` or `2-D plots` with `bqplot`.

# %% [markdown]
# ## Getting the notebook ready
# Let's ensure we have the relevant packages installed.
#
# ### Step 1: Install the relevant packages

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.12.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.4 kB 320.0 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.4 kB 262.6 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 319.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.4)
# Downloading scipy-1.12.0-cp312-cp312-win_amd64.whl (45.8 MB)
#    ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.8 MB 1.7 MB/s eta 0:00:28
#    ---------------------------------------- 0.1/45.8 MB 1.1 MB/s eta 0:00:44
#    ---------------------------------------- 0.2/45.8 MB 1.4 MB/s eta 0:00:33
#    ---------------------------------------- 0.2/45.8 MB 1.4 MB/s eta 0:00:34
#    ---------------------------------------- 0.3/45.8 MB 1.4 MB/s eta 0:00:34
#    ---------------------------------------- 0.4/45.8 MB 1.4 MB/s eta 0:00:32
#    ---------------------------------------- 0.5/45.8 MB 1.4 MB/s eta 0:00:33
#    ---------------------------------------- 0.5/45.8 MB 1.5 MB/s eta 0:00:32
#     --------------------------------------- 0.6/45.8 MB 1.4 MB/s eta 0:00:32
#     --------------------------------------- 0.7/45.8 MB 1.5 MB/s eta 0:00:31
#     --------------------------------------- 0.7/45.8 MB 1.5 MB/s eta 0:00:31
#     --------------------------------------- 0.8/45.8 MB 1.5 MB/s eta 0:00:31
#     --------------------------------------- 0.9/45.8 MB 1.5 MB/s eta 0:00:31
#     --------------------------------------- 1.0/45.8 MB 1.5 MB/s eta 0:00:31
#     --------------------------------------- 1.0/45.8 MB 1.5 MB/s eta 0:00:30
#     --------------------------------------- 1.1/45.8 MB 1.5 MB/s eta 0:00:31
#    - -------------------------------------- 1.2/45.8 MB 1.5 MB/s eta 0:00:31
kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (1.26.4)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (2.2.0)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (5.18.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (1.16.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Collecting setuptools>=34.4.1 (from cufflinks)
#   Using cached setuptools-69.0.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (8.21.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cufflinks) (8.1.1)
# Requirement already satisfied: decorator in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.1)
# Requirement already satisfied: colorama in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19.2->cufflinks) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.19.2->cufflinks) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.2.3)
# Requirement already satisfied: packaging in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from plotly>=4.1.1->cufflinks) (23.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)
# Using cached setuptools-69.0.3-py3-none-any.whl (819 kB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68725 sha256=c4c4dccc7f06d8bcc6d46aefa7e82bb211c507ace41a8f9dd147468b52a4dd60
#   Stored in directory: c:\users\zakar\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# Installing collected packages: colorlover, setuptools, cufflinks
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 setuptools-69.0.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 2: Enable interactive visualisations in Jupyter

# %%
# !pip install notebook
# Out:
# Requirement already satisfied: notebook in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (7.0.7)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from notebook) (2.12.5)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from notebook) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from notebook) (4.1.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from notebook) (6.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.1.0)
# Requirement already satisfied: jinja2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.3)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.2)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.15.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.2)
# Requirement already satisfied: overrides in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: packaging in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (23.2)
# Requirement already satisfied: prometheus-client in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.19.0)
# Requirement already satisfied: pywinpty in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.12)
# Requirement already satisfied: pyzmq>=24 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.0)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.1)
# Requirement already satisfied: websocket-client in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook) (0.26.0)
# Requirement already satisfied: ipykernel in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook) (6.29.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook) (2.2.2)
# Requirement already satisfied: babel>=2.10 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (4.21.1)
# Requirement already satisfied: requests>=2.31 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (3.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: certifi in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.0.2->notebook) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.0.2->notebook) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<5,>=4.0.2->notebook) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (306)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.17.2)
# Requirement already satisfied: tinycss2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook) (2.2.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (8.21.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (1.6.0)
# Requirement already satisfied: psutil in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.9.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: decorator in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.6.3)
# Requirement already satisfied: colorama in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.4.6)
# Requirement already satisfied: fqdn in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.4)
# Requirement already satisfied: uri-template in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\zakar\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.8.19.20240106)

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %% [markdown]
# ### Step 3: Import the required packages

# %%
# Standard data science helpers
import numpy as np
import pandas as pd
import scipy

# Instantiate the Plotly charting library.
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.express as px
# We use plotly.offline as this allows us to create interactive 
# visualisations without the use of an internet connection, 
# making our notebook more distributable to others. 
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

# The Cufflinks library allows us to directly bind 
# Pandas DataFrames to Plotly charts. 
import cufflinks as cf
# Once again, we use the Cufflinks library in offline mode. 
cf.go_offline(connected=True)
cf.set_config_file(colorscale='plotly', world_readable=True)

# Extra options. We use these to make our interactive 
# visualisations more aesthetically appealing. 
from IPython.core.display import HTML
pd.options.display.max_rows = 30
pd.options.display.max_columns = 25

# Show all code cells outputs.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Step 4: Read in the data

# %% [markdown]
# For this project, we'll work with some stats data from `medium.com`.

# %%
df = pd.read_parquet('https://github.com/WillKoehrsen/Data-Analysis/blob/master/medium/data/medium_data_2019_01_26?raw=true')
df.head()
# Out:
#      claps  days_since_publication  fans  \
# 129      2              597.301123     2
# 125     18              589.983168     3
# 132     51              577.363292    20
# 126      0              576.520688     0
# 121      0              572.533035     0
#
#                                                   link  num_responses  \
# 129  https://medium.com/p/screw-the-environment-but...              0
# 125  https://medium.com/p/the-vanquishing-of-war-pl...              0
# 132  https://medium.com/p/capstone-project-mercedes...              0
# 126  https://medium.com/p/home-of-the-scared-5af0fe...              0
# 121  https://medium.com/p/the-triumph-of-peace-f485...              0
#
#     publication      published_date  read_ratio  read_time  reads  \
# 129        None 2017-06-10 14:25:00       42.17          7     70
# 125        None 2017-06-17 22:02:00       30.34         14     54
# 132        None 2017-06-30 12:55:00       20.02         42    222
# 126        None 2017-07-01 09:08:00       35.85          9     19
# 121        None 2017-07-05 08:51:00        8.47         14      5
#
#            started_date                                           tags  \
# 129 2017-06-10 14:24:00                    [Climate Change, Economics]
# 125 2017-06-17 22:02:00  [Climate Change, Humanity, Optimism, History]
# 132 2017-06-30 12:00:00    [Machine Learning, Python, Udacity, Kaggle]
# 126 2017-06-30 18:21:00       [Politics, Books, News, Media Criticism]
# 121 2017-07-03 20:18:00         [Books, Psychology, History, Humanism]
#
#                                                   text  \
# 129  Screw the Environment, but Consider Your Walle...
# 125  The Vanquishing of War, Plague and Famine Part...
# 132  Capstone Project: Mercedes-Benz Greener Manufa...
# 126  Home of the Scared A review of A Culture of Fe...
# 121  The Triumph of Peace A review of The Better An...
#
#                                                  title  title_word_count  \
# 129    Screw the Environment, but Consider Your Wallet                 8
# 125          The Vanquishing of War, Plague and Famine                 8
# 132  Capstone Project: Mercedes-Benz Greener Manufa...                 7
# 126                                 Home of the Scared                 4
# 121                               The Triumph of Peace                 4
#
#           type  views  word_count  claps_per_word  editing_days  \
# 129  published    166        1859        0.001076             0
# 125  published    178        3891        0.004626             0
# 132  published   1109       12025        0.004241             0
# 126  published     53        2533        0.000000             0
# 121  published     59        3892        0.000000             1
#
#      <tag>Education  <tag>Data Science  <tag>Towards Data Science  \
# 129               0                  0                          0
# 125               0                  0                          0
# 132               0                  0                          0
# 126               0                  0                          0
# 121               0                  0                          0
#
#      <tag>Machine Learning  <tag>Python
# 129                      0            0
# 125                      0            0
# 132                      1            1
# 126                      0            0
# 121                      0            0

# %% [markdown]
# Let's have a quick descriptive look at the data we've just pulled:

# %%
df.describe()
# Out:
#               claps  days_since_publication         fans  num_responses  \
# count    133.000000              133.000000   133.000000     133.000000
# mean    1815.263158              248.407273   352.052632       7.045113
# min        0.000000                1.218629     0.000000       0.000000
# 25%      121.000000               74.543822    23.000000       0.000000
# 50%      815.000000              245.416130   136.000000       4.000000
# 75%     2700.000000              376.080598   528.000000      12.000000
# max    13600.000000              597.301123  2588.000000      59.000000
# std     2449.074661              179.370879   479.060117       9.056108
#
#                    published_date  read_ratio   read_time         reads  \
# count                         133  133.000000  133.000000    133.000000
# mean   2018-05-25 11:51:41.954000   29.074662   12.917293   6336.300752
# min           2017-06-10 14:25:00    8.110000    1.000000      1.000000
# 25%           2018-01-17 19:42:00   20.020000    8.000000    363.000000
# 50%           2018-05-28 11:39:00   27.060000   10.000000   2049.000000
# 75%           2018-11-15 08:35:00   34.910000   14.000000   7815.000000
# max           2019-01-27 16:23:00   74.370000   54.000000  41978.000000
# std                           NaN   12.417670    9.510795   9007.284726
#
#                      started_date  title_word_count          views  \
# count                         133        133.000000     133.000000
# mean   2018-05-04 16:41:25.714000          7.127820   23404.030075
# min           2017-06-10 14:24:00          2.000000       3.000000
# 25%           2018-01-10 08:20:00          5.000000    1375.000000
# 50%           2018-04-28 13:02:00          7.000000    7608.000000
# 75%           2018-10-14 08:24:00          8.000000   30141.000000
# max           2019-01-27 06:26:00         16.000000  173714.000000
# std                           NaN          3.158475   33995.636496
#
#          word_count  claps_per_word  editing_days  <tag>Education  \
# count    133.000000      133.000000    133.000000      133.000000
# mean    3029.120301        0.957638     20.330827        0.729323
# min      163.000000        0.000000    -13.000000        0.000000
# 25%     1653.000000        0.052115      0.000000        0.000000
# 50%     2456.000000        0.421525      1.000000        1.000000
# 75%     3553.000000        1.099366      5.000000        1.000000
# max    15063.000000       17.891817    349.000000        1.000000
# std     2393.414456        1.846756     74.111579        0.445989
#
#        <tag>Data Science  <tag>Towards Data Science  <tag>Machine Learning  \
# count         133.000000                 133.000000             133.000000
# mean            0.609023                   0.436090               0.383459
# min             0.000000                   0.000000               0.000000
# 25%             0.000000                   0.000000               0.000000
# 50%             1.000000                   0.000000               0.000000
# 75%             1.000000                   1.000000               1.000000
# max             1.000000                   1.000000               1.000000
# std             0.489814                   0.497774               0.488067
#
#        <tag>Python
# count   133.000000
# mean      0.315789
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
# std       0.466587

# %% [markdown]
# ## Interactive visualisations
# We'll now work through a few examples of interactive visualisations. We'll start with a simple filter to see how the interface works.

# %% [markdown]
# ### Example 1

# %%
from ipywidgets import interact, interact_manual, widgets

# %% [markdown]
# To make a function interactive, we need to use the ```@interact``` decorator.
#
# But wait, what's a decorator?
#
# Simply put, a decorator is a Python function that wraps around another declared function to enhance or augment its behaviour, like putting a ribbon around a present to make it look prettier as a gift. We won't go into the semantics of how to _create_ a decorator, but you can easily spot them above a function with the form ``@decorator_name``.
# For more information, see: https://realpython.com/primer-on-python-decorators/
#
# Consider the code below.

# %%
@interact
def show_articles_more_than(column='claps', x=5000):
    display(HTML(f'<h4>Showing articles with more than {x} {column}<h4>'))
    display(df.loc[df[column] > x, ['title', 'claps', 'published_date', 'read_time', 'tags', 'views', 'reads']])
# Out:
# interactive(children=(Text(value='claps', description='column'), IntSlider(value=5000, description='x', max=15…

# %% [markdown]
# The ```@interact``` decorator automatically inferred that we wanted a text box for the column and an interactive slider. This decorator makes it incredibly simple to add interactivity.

# %% [markdown]
# ### Example 2

# %% [markdown]
# Now we will add a dropdown menu to select which column to filter on while simultaneously adding limits for x.
#
# A dropdown menu can be useful when we need to enforce constraints on the interaction.

# %%
@interact
def show_titles_more_than(x=(10, 50000, 10),
                          column=['read_time', 'views', 'reads']):
    display(HTML(f'<h4>Showing articles with more than {x} {column}<h4>'))
    display(df.loc[df[column] > x, ['title', 'published_date', 'read_time', 'tags', 'views', 'reads']])
# Out:
# interactive(children=(IntSlider(value=25000, description='x', max=50000, min=10, step=10), Dropdown(descriptio…

# %% [markdown]
# ### Example 3

# %% [markdown]
# Moving on to more sophisticated data relationships that may be interactively represented, we construct a widget that quickly finds the correlation between two columns in the dataset.

# %%
@interact
def correlations(column1=list(df.select_dtypes('number').columns), 
                 column2=list(df.select_dtypes('number').columns)):
    print(f"Correlation: {df[column1].corr(df[column2])}")
# Out:
# interactive(children=(Dropdown(description='column1', options=('claps', 'days_since_publication', 'fans', 'num…

# %% [markdown]
# Within the above code example, we need to specify Pandas columns that are of a numeric type using the code `df.select_dtypes('number')` because the correlation statistic is only defined between numeric values.

# %% [markdown]
# ### Example 4

# %% [markdown]
# We can use the same basic approach to create interactive widgets for plots. This approach allows us to expand the capabilities of the powerful `plotly` visualisation library.

# %%
@interact
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:]):
    if x == y:
        print(f"Please select separate variables for X and Y")
    else:
        df.iplot(kind='scatter', x=x, y=y, mode='markers', 
                 xTitle=x.title(), yTitle=y.title(), title=f'{y.title()} vs {x.title()}')
        ## If you are using Google Colab, comment out the above line of code and uncomment the lines below
        #fig = px.scatter(df, x=x, y=y, title=f'{y.title()} vs {x.title()}')
        #fig.show(renderer="colab")
# Out:
# interactive(children=(Dropdown(description='x', options=('claps', 'days_since_publication', 'fans', 'num_respo…

# %% [markdown]
# ### Example 5

# %% [markdown]
# In a similar fashion to the previous example, we can create a customisable heatmap of correlations:

# %%
cscales = ['Greys', 'YlGnBu', 'Greens', 'YlOrRd', 'Bluered', 'RdBu',
            'Reds', 'Blues', 'Picnic', 'Rainbow', 'Portland', 'Jet',
            'Hot', 'Blackbody', 'Earth', 'Electric', 'Viridis', 'Cividis']

# We use the Figure Factory module of Plotly, which
# defines many unique and powerful plots to be used
# in Python. 
# For more info, see: https://plot.ly/python/figure-factory-subplots/
import plotly.figure_factory as ff

corrs = df.corr(numeric_only=True)

@interact
def plot_corrs(colorscale=cscales):
    figure = ff.create_annotated_heatmap(z = corrs.round(2).values, 
                                     x =list(corrs.columns), 
                                     y=list(corrs.index), 
                                     colorscale=colorscale,
                                     annotation_text=corrs.round(2).values)
    iplot(figure)
    ## If you are using Google Colab, comment out the above line of code and uncomment the line below
    #figure.show(renderer="colab")
# Out:
# interactive(children=(Dropdown(description='colorscale', options=('Greys', 'YlGnBu', 'Greens', 'YlOrRd', 'Blue…

# %% [markdown]
# ### Example 6

# %% [markdown]
# Interaction can also be extremely useful when we want to try and view various configurations for a plot that we are trying to produce.
#
# The following code allows us to add some options to control the colour scheme of a given Plotly chart. Here we call the `@interact_manual` decorator, which allows us to select multiple variables before our chart is updated.

# %%
@interact_manual
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:],
                 theme=list(cf.themes.THEMES.keys()), 
                 colorscale=list(cf.colors._scales_names.keys())):
    
    if x == y:
        print(f"Please select separate variables for X and Y")
    else:
        df.iplot(kind='scatter', x=x, y=y, mode='markers', 
                 xTitle=x.title(), yTitle=y.title(), 
                 text='title',
                 title=f'{y.title()} vs {x.title()}',
                theme=theme, colorscale=colorscale)
        ## If you are using Google Colab, comment out the above line of code and uncomment the line below
        #fig = px.scatter(df, x=x, y=y, title=f'{y.title()} vs {x.title()}')
        #fig.show(renderer="colab")
# Out:
# interactive(children=(Dropdown(description='x', options=('claps', 'days_since_publication', 'fans', 'num_respo…

# %% [markdown]
# ### Example 7

# %% [markdown]
# The decorator ```@interact``` is not the only way to use widgets.
#
# Read through the following example to figure out how else we can use widgets.

# %%
df.set_index('published_date', inplace=True)

# %%
def print_articles_published(start_date, end_date):
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date)
    stat_df = df.loc[(df.index >= start_date) & (df.index <= end_date)].copy()
    total_words = stat_df['word_count'].sum()
    total_read_time = stat_df['read_time'].sum()
    num_articles = len(stat_df)
    print(f'According to our dataset, published by Medium.com, there are {num_articles} articles between {start_date.date()} and {end_date.date()}.')
    print(f'These articles totalled {total_words:,} words and {total_read_time/60:.2f} hours to read.')
    
_ = interact(print_articles_published,
             start_date=widgets.DatePicker(value=pd.to_datetime('2018-01-01')),
             end_date=widgets.DatePicker(value=pd.to_datetime('2019-01-01')))
# Out:
# interactive(children=(DatePicker(value=Timestamp('2018-01-01 00:00:00'), description='start_date', step=1), Da…

# %% [markdown]
# ### Example 8

# %% [markdown]
# For our final example, we use the `Dropdown` and `DatePicker` widgets to plot one column cumulatively up to a certain time.

# %%
def plot_up_to(column, date):
    date = pd.Timestamp(date)
    plot_df = df.loc[df.index <= date].copy()
    plot_df[column].cumsum().iplot(mode='markers+lines', 
                                   xTitle='published date',
                                   yTitle=column, 
                                  title=f'Cumulative {column.title()} Until {date.date()}')
    
_ = interact(plot_up_to, column=widgets.Dropdown(options=list(df.select_dtypes('number').columns)), 
             date = widgets.DatePicker(value=pd.to_datetime('2019-01-01')))
# Out:
# interactive(children=(Dropdown(description='column', options=('claps', 'days_since_publication', 'fans', 'num_…

# %% [markdown]
# ## Summary

# %% [markdown]
# Jupyter Notebook is a great data exploration and analysis environment. Using tools like notebook extensions and interactive widgets makes our job as data-driven storytellers even more efficient. Widgets are powerful tools that allow us to make our data more interactive and, therefore, more accessible to non-data scientists.

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
